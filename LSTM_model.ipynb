# %%
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
import seaborn as sns
import numpy as np
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from matplotlib import pyplot as plt
import keras
from keras import initializers
import tensorflow as tf
from keras import backend as K
from keras.backend import *
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Layer, Lambda, Input, Flatten, Dropout, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, LSTM, TimeDistributed, ConvLSTM2D, Permute, Reshape, Conv2D
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import math_ops
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# %%
# load a single file as a numpy array
def load_file(filepath):
    dataframe = read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    print('File Path : ',filepath)
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load all train
X_train, Y_train = load_dataset_group('train', 'UCIDataset/')
# load all test
X_test, Y_test = load_dataset_group('test', 'UCIDataset/')

# zero-offset class values
Y_train = Y_train - 1
Y_test = Y_test - 1
# one hot encode y
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print('X_train.shape : ', X_train.shape)
print('Y_train.shape : ', Y_train.shape)
print('X_test.shape : ', X_test.shape)
print('Y_test.shape : ', Y_test.shape)
# Out:
# File Path :  UCIDataset/train/Inertial Signals/
# File Path :  UCIDataset/test/Inertial Signals/
# X_train.shape :  (7352, 128, 9)
# Y_train.shape :  (7352, 6)
# X_test.shape :  (2947, 128, 9)
# Y_test.shape :  (2947, 6)

# %%
verbose = 1
epochs = 50
batch_size = 128

n_timesteps = X_train.shape[1]
n_features = X_train.shape[2]
n_outputs = Y_train.shape[1]

# %%
checkpoint = ModelCheckpoint("lstm_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(n_timesteps, n_features)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test),
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=[checkpoint])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               70656
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 79,302
# Trainable params: 79,302
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 58/58 [==============================] - ETA: 0s - loss: 1.3826 - accuracy: 0.4106
# Epoch 1: val_accuracy improved from -inf to 0.51985, saving model to lstm_weights.h5
# 58/58 [==============================] - 9s 128ms/step - loss: 1.3826 - accuracy: 0.4106 - val_loss: 1.1687 - val_accuracy: 0.5199
# Epoch 2/50
# 58/58 [==============================] - ETA: 0s - loss: 1.0285 - accuracy: 0.5619
# Epoch 2: val_accuracy improved from 0.51985 to 0.64710, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 119ms/step - loss: 1.0285 - accuracy: 0.5619 - val_loss: 0.8405 - val_accuracy: 0.6471
# Epoch 3/50
# 58/58 [==============================] - ETA: 0s - loss: 0.8968 - accuracy: 0.6182
# Epoch 3: val_accuracy improved from 0.64710 to 0.67119, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 119ms/step - loss: 0.8968 - accuracy: 0.6182 - val_loss: 0.7818 - val_accuracy: 0.6712
# Epoch 4/50
# 58/58 [==============================] - ETA: 0s - loss: 0.7282 - accuracy: 0.6873
# Epoch 4: val_accuracy improved from 0.67119 to 0.73736, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 118ms/step - loss: 0.7282 - accuracy: 0.6873 - val_loss: 0.6785 - val_accuracy: 0.7374
# Epoch 5/50
# 58/58 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.7701
# Epoch 5: val_accuracy improved from 0.73736 to 0.80794, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 121ms/step - loss: 0.5891 - accuracy: 0.7701 - val_loss: 0.5652 - val_accuracy: 0.8079
# Epoch 6/50
# 58/58 [==============================] - ETA: 0s - loss: 0.5184 - accuracy: 0.8162
# Epoch 6: val_accuracy did not improve from 0.80794
# 58/58 [==============================] - 7s 121ms/step - loss: 0.5184 - accuracy: 0.8162 - val_loss: 0.6338 - val_accuracy: 0.7767
# Epoch 7/50
# 58/58 [==============================] - ETA: 0s - loss: 0.5002 - accuracy: 0.8092
# Epoch 7: val_accuracy did not improve from 0.80794
# 58/58 [==============================] - 7s 118ms/step - loss: 0.5002 - accuracy: 0.8092 - val_loss: 0.6221 - val_accuracy: 0.7604
# Epoch 8/50
# 58/58 [==============================] - ETA: 0s - loss: 0.4425 - accuracy: 0.8417
# Epoch 8: val_accuracy improved from 0.80794 to 0.84561, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 117ms/step - loss: 0.4425 - accuracy: 0.8417 - val_loss: 0.4965 - val_accuracy: 0.8456
# Epoch 9/50
# 58/58 [==============================] - ETA: 0s - loss: 0.3342 - accuracy: 0.8942
# Epoch 9: val_accuracy improved from 0.84561 to 0.85816, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 119ms/step - loss: 0.3342 - accuracy: 0.8942 - val_loss: 0.4975 - val_accuracy: 0.8582
# Epoch 10/50
# 58/58 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9015
# Epoch 10: val_accuracy did not improve from 0.85816
# 58/58 [==============================] - 7s 127ms/step - loss: 0.3053 - accuracy: 0.9015 - val_loss: 0.6211 - val_accuracy: 0.7798
# Epoch 11/50
# 58/58 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.8787
# Epoch 11: val_accuracy improved from 0.85816 to 0.86834, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.3615 - accuracy: 0.8787 - val_loss: 0.4116 - val_accuracy: 0.8683
# Epoch 12/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.9089
# Epoch 12: val_accuracy improved from 0.86834 to 0.88802, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2715 - accuracy: 0.9089 - val_loss: 0.4051 - val_accuracy: 0.8880
# Epoch 13/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9298
# Epoch 13: val_accuracy improved from 0.88802 to 0.89617, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.2006 - accuracy: 0.9298 - val_loss: 0.4152 - val_accuracy: 0.8962
# Epoch 14/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9274
# Epoch 14: val_accuracy improved from 0.89617 to 0.89752, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 132ms/step - loss: 0.2183 - accuracy: 0.9274 - val_loss: 0.3411 - val_accuracy: 0.8975
# Epoch 15/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.9271
# Epoch 15: val_accuracy did not improve from 0.89752
# 58/58 [==============================] - 8s 131ms/step - loss: 0.2563 - accuracy: 0.9271 - val_loss: 0.4172 - val_accuracy: 0.8928
# Epoch 16/50
# 58/58 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9064
# Epoch 16: val_accuracy did not improve from 0.89752
# 58/58 [==============================] - 7s 129ms/step - loss: 0.3083 - accuracy: 0.9064 - val_loss: 0.4780 - val_accuracy: 0.8707
# Epoch 17/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9308
# Epoch 17: val_accuracy did not improve from 0.89752
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1934 - accuracy: 0.9308 - val_loss: 0.3906 - val_accuracy: 0.8921
# Epoch 18/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9384
# Epoch 18: val_accuracy improved from 0.89752 to 0.90058, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1704 - accuracy: 0.9384 - val_loss: 0.3875 - val_accuracy: 0.9006
# Epoch 19/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9415
# Epoch 19: val_accuracy did not improve from 0.90058
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1898 - accuracy: 0.9415 - val_loss: 0.3738 - val_accuracy: 0.8958
# Epoch 20/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9437
# Epoch 20: val_accuracy improved from 0.90058 to 0.90397, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1486 - accuracy: 0.9437 - val_loss: 0.4058 - val_accuracy: 0.9040
# Epoch 21/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9399
# Epoch 21: val_accuracy did not improve from 0.90397
# 58/58 [==============================] - 7s 123ms/step - loss: 0.1718 - accuracy: 0.9399 - val_loss: 0.3412 - val_accuracy: 0.8982
# Epoch 22/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9441
# Epoch 22: val_accuracy improved from 0.90397 to 0.90601, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 117ms/step - loss: 0.1565 - accuracy: 0.9441 - val_loss: 0.4314 - val_accuracy: 0.9060
# Epoch 23/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9453
# Epoch 23: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 126ms/step - loss: 0.1501 - accuracy: 0.9453 - val_loss: 0.3856 - val_accuracy: 0.9016
# Epoch 24/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9255
# Epoch 24: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 128ms/step - loss: 0.2434 - accuracy: 0.9255 - val_loss: 0.8353 - val_accuracy: 0.8585
# Epoch 25/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9457
# Epoch 25: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1669 - accuracy: 0.9457 - val_loss: 0.5218 - val_accuracy: 0.8768
# Epoch 26/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9353
# Epoch 26: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1804 - accuracy: 0.9353 - val_loss: 0.3833 - val_accuracy: 0.9016
# Epoch 27/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9430
# Epoch 27: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1450 - accuracy: 0.9430 - val_loss: 0.4335 - val_accuracy: 0.8999
# Epoch 28/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9377
# Epoch 28: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1518 - accuracy: 0.9377 - val_loss: 0.5254 - val_accuracy: 0.9033
# Epoch 29/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9423
# Epoch 29: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1362 - accuracy: 0.9423 - val_loss: 0.4385 - val_accuracy: 0.9060
# Epoch 30/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9491
# Epoch 30: val_accuracy did not improve from 0.90601
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1283 - accuracy: 0.9491 - val_loss: 0.5069 - val_accuracy: 0.9046
# Epoch 31/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1440 - accuracy: 0.9412
# Epoch 31: val_accuracy improved from 0.90601 to 0.90804, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1440 - accuracy: 0.9412 - val_loss: 0.4977 - val_accuracy: 0.9080
# Epoch 32/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9479
# Epoch 32: val_accuracy did not improve from 0.90804
# 58/58 [==============================] - 8s 131ms/step - loss: 0.1299 - accuracy: 0.9479 - val_loss: 0.4369 - val_accuracy: 0.9030
# Epoch 33/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9510
# Epoch 33: val_accuracy improved from 0.90804 to 0.91245, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 128ms/step - loss: 0.1353 - accuracy: 0.9510 - val_loss: 0.3975 - val_accuracy: 0.9125
# Epoch 34/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9513
# Epoch 34: val_accuracy improved from 0.91245 to 0.91551, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 139ms/step - loss: 0.1192 - accuracy: 0.9513 - val_loss: 0.4600 - val_accuracy: 0.9155
# Epoch 35/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9543
# Epoch 35: val_accuracy improved from 0.91551 to 0.91653, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1158 - accuracy: 0.9543 - val_loss: 0.4934 - val_accuracy: 0.9165
# Epoch 36/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9328
# Epoch 36: val_accuracy did not improve from 0.91653
# 58/58 [==============================] - 8s 137ms/step - loss: 0.2125 - accuracy: 0.9328 - val_loss: 0.4726 - val_accuracy: 0.9108
# Epoch 37/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9493
# Epoch 37: val_accuracy did not improve from 0.91653
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1364 - accuracy: 0.9493 - val_loss: 0.2684 - val_accuracy: 0.9114
# Epoch 38/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9489
# Epoch 38: val_accuracy improved from 0.91653 to 0.91992, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1213 - accuracy: 0.9489 - val_loss: 0.2746 - val_accuracy: 0.9199
# Epoch 39/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9547
# Epoch 39: val_accuracy did not improve from 0.91992
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1197 - accuracy: 0.9547 - val_loss: 0.2789 - val_accuracy: 0.9172
# Epoch 40/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9514
# Epoch 40: val_accuracy did not improve from 0.91992
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1254 - accuracy: 0.9514 - val_loss: 0.2998 - val_accuracy: 0.9155
# Epoch 41/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9478
# Epoch 41: val_accuracy improved from 0.91992 to 0.92094, saving model to lstm_weights.h5
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1265 - accuracy: 0.9478 - val_loss: 0.2747 - val_accuracy: 0.9209
# Epoch 42/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9538
# Epoch 42: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 8s 130ms/step - loss: 0.1153 - accuracy: 0.9538 - val_loss: 0.3258 - val_accuracy: 0.9175
# Epoch 43/50
# 58/58 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.8615
# Epoch 43: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 7s 128ms/step - loss: 0.4175 - accuracy: 0.8615 - val_loss: 0.3934 - val_accuracy: 0.8429
# Epoch 44/50
# 58/58 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.9018
# Epoch 44: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 7s 127ms/step - loss: 0.2536 - accuracy: 0.9018 - val_loss: 0.3670 - val_accuracy: 0.8965
# Epoch 45/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9346
# Epoch 45: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1896 - accuracy: 0.9346 - val_loss: 0.4771 - val_accuracy: 0.8931
# Epoch 46/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9396
# Epoch 46: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 7s 127ms/step - loss: 0.1625 - accuracy: 0.9396 - val_loss: 0.5816 - val_accuracy: 0.8802
# Epoch 47/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9378
# Epoch 47: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 8s 137ms/step - loss: 0.1718 - accuracy: 0.9378 - val_loss: 0.3893 - val_accuracy: 0.9033
# Epoch 48/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9423
# Epoch 48: val_accuracy did not improve from 0.92094
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1450 - accuracy: 0.9423 - val_loss: 0.3373 - val_accuracy: 0.9128
# Epoch 49/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9453
# Epoch 49: val_accuracy improved from 0.92094 to 0.92704, saving model to lstm_weights.h5
# 58/58 [==============================] - 8s 133ms/step - loss: 0.1455 - accuracy: 0.9453 - val_loss: 0.3309 - val_accuracy: 0.9270
# Epoch 50/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9527
# Epoch 50: val_accuracy did not improve from 0.92704
# 58/58 [==============================] - 8s 134ms/step - loss: 0.1337 - accuracy: 0.9527 - val_loss: 0.3303 - val_accuracy: 0.9223

# %%
# Maximum validation Accuracy
val_accuracy_tensor = history.history['val_accuracy']
best_val_accuracy = np.max(val_accuracy_tensor)
print("Best Validation Accuracy:", best_val_accuracy)

# confusion matrix
LABELS = ['WALKING',
          'WALKING_UPSTAIRS',
          'WALKING_DOWNSTAIRS',
          'SITTING',
          'STANDING',
          'LAYING']
best_model = load_model("LSTM_weights.h5")
y_pred_test = best_model.predict(X_test)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(Y_test, axis=1)

true_classes = np.argmax(Y_test, axis=1)
predicted_classes = np.argmax(y_pred_test, axis=1)
report = classification_report(true_classes, predicted_classes, digits=4)
print("Classification Report:\n", report)

matrix = metrics.confusion_matrix(max_y_test, max_y_pred_test)
plt.figure(figsize=(6, 4))
sns.heatmap(matrix,
            cmap='coolwarm',
            linecolor='white',
            linewidths=1,
            xticklabels=LABELS,
            yticklabels=LABELS,
            annot=True,
            fmt='d')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Best Validation Accuracy: 0.9270444512367249
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9606    0.9335    0.9468       496
#            1     0.9469    0.9469    0.9469       471
#            2     0.9170    1.0000    0.9567       420
#            3     0.8562    0.8248    0.8402       491
#            4     0.8764    0.8665    0.8715       532
#            5     1.0000    1.0000    1.0000       537
#
#     accuracy                         0.9270      2947
#    macro avg     0.9262    0.9286    0.9270      2947
# weighted avg     0.9268    0.9270    0.9266      2947
