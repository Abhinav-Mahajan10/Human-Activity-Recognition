# %%
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
import seaborn as sns
import numpy as np
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from matplotlib import pyplot as plt
import keras
from keras import initializers
import tensorflow as tf
from keras import backend as K
from keras.backend import *
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Layer, Lambda, Input, Flatten, Dropout, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, LSTM, TimeDistributed, ConvLSTM2D, Permute, Reshape, Conv2D
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import math_ops
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# %%
# load a single file as a numpy array
def load_file(filepath):
    dataframe = read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    print('File Path : ',filepath)
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load all train
X_train, Y_train = load_dataset_group('train', 'UCIDataset/')
# load all test
X_test, Y_test = load_dataset_group('test', 'UCIDataset/')

# zero-offset class values
Y_train = Y_train - 1
Y_test = Y_test - 1
# one hot encode y
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print('X_train.shape : ', X_train.shape)
print('Y_train.shape : ', Y_train.shape)
print('X_test.shape : ', X_test.shape)
print('Y_test.shape : ', Y_test.shape)
# Out:
# File Path :  UCIDataset/train/Inertial Signals/
# File Path :  UCIDataset/test/Inertial Signals/
# X_train.shape :  (7352, 128, 9)
# Y_train.shape :  (7352, 6)
# X_test.shape :  (2947, 128, 9)
# Y_test.shape :  (2947, 6)

# %%
verbose = 1
epochs = 50
batch_size = 128

n_timesteps = X_train.shape[1]
n_features = X_train.shape[2]
n_outputs = Y_train.shape[1]

# %%
checkpoint = ModelCheckpoint("CNN_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

# %%
model = Sequential()
model.add(Conv1D(filters=128, kernel_size=4, activation='relu', input_shape=(n_timesteps,n_features)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=128, kernel_size=4, activation='relu', padding = 'same'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()


history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test),
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=[checkpoint])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 125, 128)          4736
#
#  max_pooling1d (MaxPooling1D  (None, 62, 128)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 62, 128)           65664
#
#  dropout (Dropout)           (None, 62, 128)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 31, 128)          0
#  1D)
#
#  flatten (Flatten)           (None, 3968)              0
#
#  dense (Dense)               (None, 512)               2032128
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 2,105,606
# Trainable params: 2,105,606
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 58/58 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.8082
# Epoch 1: val_accuracy improved from -inf to 0.88259, saving model to CNN_weights.h5
# 58/58 [==============================] - 4s 60ms/step - loss: 0.4850 - accuracy: 0.8082 - val_loss: 0.4040 - val_accuracy: 0.8826
# Epoch 2/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.1441 - accuracy: 0.9428
# Epoch 2: val_accuracy improved from 0.88259 to 0.88972, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 55ms/step - loss: 0.1437 - accuracy: 0.9430 - val_loss: 0.3494 - val_accuracy: 0.8897
# Epoch 3/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9509
# Epoch 3: val_accuracy improved from 0.88972 to 0.91110, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 50ms/step - loss: 0.1219 - accuracy: 0.9506 - val_loss: 0.2874 - val_accuracy: 0.9111
# Epoch 4/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9524
# Epoch 4: val_accuracy did not improve from 0.91110
# 58/58 [==============================] - 3s 47ms/step - loss: 0.1097 - accuracy: 0.9521 - val_loss: 0.2691 - val_accuracy: 0.9067
# Epoch 5/50
# 58/58 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9562
# Epoch 5: val_accuracy did not improve from 0.91110
# 58/58 [==============================] - 3s 48ms/step - loss: 0.1027 - accuracy: 0.9562 - val_loss: 0.3201 - val_accuracy: 0.9087
# Epoch 6/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0965 - accuracy: 0.9572
# Epoch 6: val_accuracy improved from 0.91110 to 0.91449, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 52ms/step - loss: 0.0967 - accuracy: 0.9570 - val_loss: 0.3160 - val_accuracy: 0.9145
# Epoch 7/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9599
# Epoch 7: val_accuracy did not improve from 0.91449
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0917 - accuracy: 0.9599 - val_loss: 0.3463 - val_accuracy: 0.9074
# Epoch 8/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9573
# Epoch 8: val_accuracy did not improve from 0.91449
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0972 - accuracy: 0.9573 - val_loss: 0.3236 - val_accuracy: 0.9145
# Epoch 9/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9585
# Epoch 9: val_accuracy did not improve from 0.91449
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0922 - accuracy: 0.9585 - val_loss: 0.3192 - val_accuracy: 0.9141
# Epoch 10/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9618
# Epoch 10: val_accuracy did not improve from 0.91449
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0876 - accuracy: 0.9618 - val_loss: 0.3286 - val_accuracy: 0.9013
# Epoch 11/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9659
# Epoch 11: val_accuracy improved from 0.91449 to 0.92331, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0745 - accuracy: 0.9659 - val_loss: 0.3626 - val_accuracy: 0.9233
# Epoch 12/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9652
# Epoch 12: val_accuracy improved from 0.92331 to 0.92806, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0738 - accuracy: 0.9652 - val_loss: 0.3943 - val_accuracy: 0.9281
# Epoch 13/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9663
# Epoch 13: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0697 - accuracy: 0.9665 - val_loss: 0.2971 - val_accuracy: 0.9135
# Epoch 14/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0653 - accuracy: 0.9678
# Epoch 14: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0649 - accuracy: 0.9679 - val_loss: 0.3234 - val_accuracy: 0.9233
# Epoch 15/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9668
# Epoch 15: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0756 - accuracy: 0.9668 - val_loss: 0.3117 - val_accuracy: 0.9172
# Epoch 16/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.1017 - accuracy: 0.9604
# Epoch 16: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 47ms/step - loss: 0.1017 - accuracy: 0.9601 - val_loss: 0.2650 - val_accuracy: 0.9189
# Epoch 17/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0763 - accuracy: 0.9657
# Epoch 17: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 47ms/step - loss: 0.0761 - accuracy: 0.9657 - val_loss: 0.3383 - val_accuracy: 0.9189
# Epoch 18/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9683
# Epoch 18: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0633 - accuracy: 0.9686 - val_loss: 0.2873 - val_accuracy: 0.9101
# Epoch 19/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0623 - accuracy: 0.9716
# Epoch 19: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 46ms/step - loss: 0.0622 - accuracy: 0.9716 - val_loss: 0.2756 - val_accuracy: 0.9260
# Epoch 20/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9698
# Epoch 20: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0593 - accuracy: 0.9698 - val_loss: 0.2919 - val_accuracy: 0.9097
# Epoch 21/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9735
# Epoch 21: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0524 - accuracy: 0.9733 - val_loss: 0.2806 - val_accuracy: 0.9260
# Epoch 22/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9724
# Epoch 22: val_accuracy did not improve from 0.92806
# 58/58 [==============================] - 3s 48ms/step - loss: 0.0543 - accuracy: 0.9724 - val_loss: 0.2728 - val_accuracy: 0.9220
# Epoch 23/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9743
# Epoch 23: val_accuracy improved from 0.92806 to 0.93213, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 55ms/step - loss: 0.0553 - accuracy: 0.9743 - val_loss: 0.2649 - val_accuracy: 0.9321
# Epoch 24/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0558 - accuracy: 0.9730
# Epoch 24: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 52ms/step - loss: 0.0557 - accuracy: 0.9731 - val_loss: 0.2588 - val_accuracy: 0.9175
# Epoch 25/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9748
# Epoch 25: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0507 - accuracy: 0.9748 - val_loss: 0.3027 - val_accuracy: 0.9230
# Epoch 26/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0532 - accuracy: 0.9744
# Epoch 26: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0529 - accuracy: 0.9746 - val_loss: 0.2716 - val_accuracy: 0.9172
# Epoch 27/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0530 - accuracy: 0.9748
# Epoch 27: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0531 - accuracy: 0.9748 - val_loss: 0.2917 - val_accuracy: 0.9260
# Epoch 28/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0488 - accuracy: 0.9770
# Epoch 28: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0488 - accuracy: 0.9770 - val_loss: 0.2982 - val_accuracy: 0.9277
# Epoch 29/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9777
# Epoch 29: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 52ms/step - loss: 0.0452 - accuracy: 0.9778 - val_loss: 0.5770 - val_accuracy: 0.8819
# Epoch 30/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9758
# Epoch 30: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0530 - accuracy: 0.9758 - val_loss: 0.2679 - val_accuracy: 0.9301
# Epoch 31/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9778
# Epoch 31: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0464 - accuracy: 0.9778 - val_loss: 0.2608 - val_accuracy: 0.9182
# Epoch 32/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9796
# Epoch 32: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 52ms/step - loss: 0.0445 - accuracy: 0.9797 - val_loss: 0.2931 - val_accuracy: 0.9145
# Epoch 33/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9816
# Epoch 33: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0421 - accuracy: 0.9816 - val_loss: 0.2992 - val_accuracy: 0.9257
# Epoch 34/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9747
# Epoch 34: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0681 - accuracy: 0.9747 - val_loss: 0.3495 - val_accuracy: 0.9053
# Epoch 35/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9742
# Epoch 35: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0593 - accuracy: 0.9742 - val_loss: 0.4365 - val_accuracy: 0.9247
# Epoch 36/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0413 - accuracy: 0.9826
# Epoch 36: val_accuracy did not improve from 0.93213
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0414 - accuracy: 0.9825 - val_loss: 0.3318 - val_accuracy: 0.9264
# Epoch 37/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9815
# Epoch 37: val_accuracy improved from 0.93213 to 0.93519, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 57ms/step - loss: 0.0398 - accuracy: 0.9815 - val_loss: 0.3116 - val_accuracy: 0.9352
# Epoch 38/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9833
# Epoch 38: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 52ms/step - loss: 0.0354 - accuracy: 0.9829 - val_loss: 0.2955 - val_accuracy: 0.9325
# Epoch 39/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9835
# Epoch 39: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0381 - accuracy: 0.9835 - val_loss: 0.2811 - val_accuracy: 0.9247
# Epoch 40/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9820
# Epoch 40: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0401 - accuracy: 0.9822 - val_loss: 0.3317 - val_accuracy: 0.9291
# Epoch 41/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9849
# Epoch 41: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0326 - accuracy: 0.9850 - val_loss: 0.3540 - val_accuracy: 0.9145
# Epoch 42/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9834
# Epoch 42: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0361 - accuracy: 0.9834 - val_loss: 0.3055 - val_accuracy: 0.9264
# Epoch 43/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9849
# Epoch 43: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 52ms/step - loss: 0.0330 - accuracy: 0.9849 - val_loss: 0.3233 - val_accuracy: 0.9281
# Epoch 44/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0274 - accuracy: 0.9877
# Epoch 44: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0274 - accuracy: 0.9876 - val_loss: 0.3299 - val_accuracy: 0.9237
# Epoch 45/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9864
# Epoch 45: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 49ms/step - loss: 0.0303 - accuracy: 0.9864 - val_loss: 0.3748 - val_accuracy: 0.9226
# Epoch 46/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9882
# Epoch 46: val_accuracy did not improve from 0.93519
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0269 - accuracy: 0.9882 - val_loss: 0.3105 - val_accuracy: 0.9281
# Epoch 47/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9867
# Epoch 47: val_accuracy improved from 0.93519 to 0.93553, saving model to CNN_weights.h5
# 58/58 [==============================] - 3s 54ms/step - loss: 0.0282 - accuracy: 0.9867 - val_loss: 0.3205 - val_accuracy: 0.9355
# Epoch 48/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9894
# Epoch 48: val_accuracy did not improve from 0.93553
# 58/58 [==============================] - 3s 50ms/step - loss: 0.0235 - accuracy: 0.9894 - val_loss: 0.3149 - val_accuracy: 0.9311
# Epoch 49/50
# 58/58 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9910
# Epoch 49: val_accuracy did not improve from 0.93553
# 58/58 [==============================] - 3s 53ms/step - loss: 0.0207 - accuracy: 0.9910 - val_loss: 0.3724 - val_accuracy: 0.9328
# Epoch 50/50
# 57/58 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9886
# Epoch 50: val_accuracy did not improve from 0.93553
# 58/58 [==============================] - 3s 51ms/step - loss: 0.0253 - accuracy: 0.9887 - val_loss: 0.3858 - val_accuracy: 0.9270

# %%
# Maximum validation Accuracy
val_accuracy_tensor = history.history['val_accuracy']
best_val_accuracy = np.max(val_accuracy_tensor)
print("Best Validation Accuracy:", best_val_accuracy)

# confusion matrix
LABELS = ['WALKING',
          'WALKING_UPSTAIRS',
          'WALKING_DOWNSTAIRS',
          'SITTING',
          'STANDING',
          'LAYING']
best_model = load_model("CNN_weights.h5")
y_pred_test = best_model.predict(X_test)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(Y_test, axis=1)

true_classes = np.argmax(Y_test, axis=1)
predicted_classes = np.argmax(y_pred_test, axis=1)
report = classification_report(true_classes, predicted_classes, digits=4)
print("Classification Report:\n", report)

matrix = metrics.confusion_matrix(max_y_test, max_y_pred_test)
plt.figure(figsize=(6, 4))
sns.heatmap(matrix,
            cmap='coolwarm',
            linecolor='white',
            linewidths=1,
            xticklabels=LABELS,
            yticklabels=LABELS,
            annot=True,
            fmt='d')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Best Validation Accuracy: 0.9355276823043823
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9959    0.9698    0.9826       496
#            1     0.9763    0.9639    0.9701       471
#            2     0.9351    0.9952    0.9642       420
#            3     0.9100    0.7617    0.8293       491
#            4     0.8247    0.9286    0.8736       532
#            5     0.9889    0.9981    0.9935       537
#
#     accuracy                         0.9355      2947
#    macro avg     0.9385    0.9362    0.9356      2947
# weighted avg     0.9376    0.9355    0.9347      2947
